# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                                          job_title  \
# 0                              Senior Data Analyst
# 1                                 Sr. Data Analyst
# 2          Master Data Management Business Analyst
# 3                              Senior Data Analyst
# 4                              Intern Data Analyst
# 5    Data Analyst - Python/Artificial Intelligence
# 6                                Lead Data Analyst
# 7                                     Data Analyst
# 8                    Leap COE Intern(Data Analyst)
# 9  Forecasting Analyst/ Data Scientist (US Client)
#
#                                         job_location  \
# 0               Bangalore/Bengaluru(Old Madras Road)
# 1                          Bangalore/Bengaluru, Pune
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# ...

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
jo_title=[]
jo_location=[]
compan_name=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    jo_title.append(title)

# %%
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    jo_location.append(location)

# %%
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    compan_name.append(company)

# %%
print(len(jo_title),len(jo_location),len(compan_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'job_title':jo_title,'job_location':jo_location,'company_name':compan_name})
df
# Out:
#                                            job_title  \
# 0                      Tcs Hiring For Data Scientist
# 1   Senior Manager - EmTech - Machine Learning - P&T
# 2                   Analystics & Modeling Specialist
# 3     Data scientist _Tata Consultancy Services(Tcs)
# 4  Job||Job Opening For AI Technologist - Data Sc...
# 5  Hiring For DATA Scientist @ NTT DATA Business ...
# 6  Urgent Job Opening For AI Practitioner - Data ...
# 7                              Data Scientist Python
# 8                   Assistant Manager - Data Science
# 9                                     Data Scientist
#
#                                         job_location  \
# 0   Bangalore/Bengaluru, Chennai, Mumbai (All Areas)
# 1  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 3  Bangalore/Bengaluru, Kochi/Cochin, Indore, New...
# 4  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# ...

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
location_filter = driver.find_element(By.XPATH,'//span[@title="Delhi / NCR"]')

location_filter.click()

# %%
salary_filter = driver.find_element(By.XPATH,'//span[@title="3-6 Lakhs"]')

salary_filter.click()

# %%
j_title=[]
j_location=[]
compa_name=[]
expe_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    j_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    j_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    compa_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    exp=i.text
    expe_required.append(exp)

# %%
df=pd.DataFrame({'job_title':j_title,'job_location':j_location,'company_name':compa_name,'experience_required':expe_required})
df
# Out:
#                                            job_title  \
# 0  Job||Job Opening For AI Technologist - Data Sc...
# 1                   Data Scientist - Noida/Bangalore
# 2                    DigitalBCG GAMMA Data Scientist
# 3              Data Scientist - Predictive Analytics
# 4                                     Data Scientist
# 5                Chat-bot Developer / Data Scientist
# 6                Data Scientist / Chat-bot Developer
# 7                  Data Scientist - Engine Algorithm
# 8         Data Scientist For Healthcare Product team
# 9                                     Data Scientist
#
#                                         job_location  \
# 0  New Delhi, Hyderabad/Secunderabad, Pune, Chenn...
# 1                         Noida, Bangalore/Bengaluru
# 2                     New Delhi, Bangalore/Bengaluru
# 3  Noida, Mumbai, Chandigarh, Hyderabad/Secundera...
# 4                                   Gurgaon/Gurugram
# 5  Mumbai, New Delhi, Bangalore/Bengaluru\n(WFH d...
# ...

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
sunglasses=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
sunglasses.send_keys('sunglasses')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
brand=[]
description=[]
price=[]
brands_tags=driver.find_elements(By.XPATH,'//*[@class="_2WkVRV"]')
for i in brands_tags[0:100]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:100]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//*[@class="_30jeq3"]')
for i in pric_tags[0:100]:
    pric=i.text
    price.append(pric)

# %%
print(len(brand),len(description),len(price))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'brand':brand,'description':description,'price':price})
df
# Out:
#                 brand                                        description  \
# 0              SUNBEE  UV Protection, Polarized, Mirrored Wayfarer Su...
# 1      ROZZETTA CRAFT   UV Protection Rectangular Sunglasses (Free Size)
# 2            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 3      ROZZETTA CRAFT           UV Protection Over-sized Sunglasses (57)
# 4           Rich Club                UV Protection Round Sunglasses (50)
# 5      ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)
# 6              AISLIN  UV Protection, Gradient Butterfly, Over-sized ...
# 7      ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...
# 8            Fastrack              Gradient Round Sunglasses (Free Size)
# 9       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 10             PIRASO              UV Protection Aviator Sunglasses (55)
# 11     ROZZETTA CRAFT        UV Protection Shield Sunglasses (Free Size)
# ...

# %%
next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next.click()

# %%
brand=[]
description=[]
price=[]
brands_tags=driver.find_elements(By.XPATH,'//*[@class="_2WkVRV"]')
for i in brands_tags[0:100]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:100]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//*[@class="_30jeq3"]')
for i in pric_tags[0:100]:
    pric=i.text
    price.append(pric)

# %%
print(len(brand),len(description),len(price))
# Out:
# 40 40 40

# %%
df1=pd.DataFrame({'brand':brand,'description':description,'price':price})
df1
# Out:
#              brand                                        description    price
# 0           GANSTA  UV Protection, Night Vision, Riding Glasses Av...     ₹349
# 1          Urbanic         Others Retro Square Sunglasses (Free Size)     ₹599
# 2    VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...     ₹899
# 3    VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...   ₹1,415
# 4          Ray-Ban               UV Protection Shield Sunglasses (51)  ₹10,390
# 5    VINCENT CHASE  Polarized, UV Protection Rectangular Sunglasse...     ₹999
# 6          Ray-Ban              UV Protection Aviator Sunglasses (58)  ₹10,257
# 7    VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...     ₹999
# 8            NuVew  UV Protection, Night Vision, Riding Glasses Av...     ₹195
# 9        ROYAL SON  UV Protection Round, Oval, Cat-eye Sunglasses ...     ₹699
# 10   VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...   ₹1,049
# ...

# %%
next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]")
next.click()

# %%
brand=[]
description=[]
price=[]
brands_tags=driver.find_elements(By.XPATH,'//*[@class="_2WkVRV"]')
for i in brands_tags[0:20]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:20]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//*[@class="_30jeq3"]')
for i in pric_tags[0:20]:
    pric=i.text
    price.append(pric)

# %%
print(len(brand),len(description),len(price))
# Out:
# 20 20 20

# %%
df2=pd.DataFrame({'brand':brand,'description':description,'price':price})
df2
# Out:
#              brand                                        description    price
# 0        ROYAL SON            Mirrored Aviator Sunglasses (Free Size)     ₹379
# 1         Fastrack       UV Protection Aviator Sunglasses (Free Size)   ₹1,499
# 2           PIRASO             Polarized Retro Square Sunglasses (47)     ₹444
# 3    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)     ₹999
# 4            NuVew               UV Protection Sports Sunglasses (73)     ₹398
# 5           GANSTA  Riding Glasses, UV Protection Aviator Sunglass...     ₹259
# 6    VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...     ₹799
# 7   ROZZETTA CRAFT     UV Protection Spectacle Sunglasses (Free Size)     ₹399
# 8          Dannilo  Gradient, UV Protection, Mirrored Round Sungla...     ₹240
# 9      john jacobs         UV Protection Retro Square Sunglasses (51)   ₹3,325
# 10     SKYZA INDIA  Polarized, UV Protection Sports Sunglasses (Fr...     ₹489
# ...

# %%
pd.concat([df, df1, df2])
# Out:
#              brand                                        description    price
# 0           SUNBEE  UV Protection, Polarized, Mirrored Wayfarer Su...     ₹283
# 1   ROZZETTA CRAFT   UV Protection Rectangular Sunglasses (Free Size)     ₹319
# 2         Fastrack   UV Protection Rectangular Sunglasses (Free Size)     ₹639
# 3   ROZZETTA CRAFT           UV Protection Over-sized Sunglasses (57)     ₹449
# 4        Rich Club                UV Protection Round Sunglasses (50)     ₹399
# ..             ...                                                ...      ...
# 15   VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...     ₹949
# 16       ROYAL SON  UV Protection, Polarized Wrap-around, Sports S...     ₹854
# 17      PHENOMENAL  UV Protection, Mirrored Wayfarer Sunglasses (F...     ₹259
# 18         Ray-Ban               UV Protection Shield Sunglasses (51)  ₹10,390
# 19   VINCENT CHASE  by Lenskart UV Protection Aviator Sunglasses (58)     ₹949
#
# [100 rows x 3 columns]

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
sunglasses=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
sunglasses.send_keys('iphone11')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
#lateron for question 5

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/")
sunglasses=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
sunglasses.send_keys('sneakers')
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
brand=[]
description=[]
price=[]
discount=[]
brands_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brands_tags[0:32]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in descriptio_tags[0:32]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in pric_tags[0:32]:
    pric=i.text
    price.append(pric)
    
discoun_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discoun_tags[0:32]:
    discoun=i.text
    discount.append(discoun)

# %%
print(len(brand),len(description),len(price),len(discount))
# Out:
# 32 32 32 32

# %%
df=pd.DataFrame({'brand':brand,'description':description,'price':price,'discount':discount})
df
# Out:
#             brand                                        description   price  \
# 0          LEVI'S      Levi's Men's Lancer Sneakers Sneakers For Men  ₹1,759
# 1          LEVI'S       Levi's Men's Henry Sneakers Sneakers For Men  ₹1,539
# 2            PUMA                      Cilia Mode Sneakers For Women  ₹2,289
# 3        RapidBox                             Glory Sneakers For Men    ₹610
# 4            PUMA                                 Sneakers For Women  ₹1,747
# 5          Layasa                                   Sneakers For Men    ₹498
# 6        Roadster  Casual Sneakers Canvas Shoes For Men Sneakers ...    ₹959
# 7        RapidBox  Unique & Perfect Collection Combo Pack of 02 S...    ₹640
# 8    Robbie jones  casual sneaker shoes for men luxury fashion ca...    ₹529
# 9          Chevit                                 Sneakers For Women    ₹459
# 10    kardam&sons                                   Sneakers For Men    ₹448
# ...

# %%
next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next.click()

# %%
brand=[]
description=[]
price=[]
discount=[]
brands_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brands_tags[0:32]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:32]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in pric_tags[0:32]:
    pric=i.text
    price.append(pric)
    
discoun_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discoun_tags[0:32]:
    discoun=i.text
    discount.append(discoun)

# %%
print(len(brand),len(description),len(price),len(discount))
# Out:
# 32 32 32 32

# %%
next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]")
next.click()

# %%
brand=[]
description=[]
price=[]
discount=[]
brands_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brands_tags[0:32]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:32]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in pric_tags[0:32]:
    pric=i.text
    price.append(pric)
    
discoun_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discoun_tags[0:32]:
    discoun=i.text
    discount.append(discoun)

# %%
print(len(brand),len(description),len(price),len(discount))
# Out:
# 32 32 32 32

# %%
df1=pd.DataFrame({'brand':brand,'description':description,'price':price,'discount':discount})
df1
# Out:
#               brand                                        description  \
# 0              PUMA                   Puma Smash Vulc Sneakers For Men
# 1              aadi  Mesh | Ultralightweight | Comfortable | Breath...
# 2          RED TAPE                                   Sneakers For Men
# 3   U.S. POLO ASSN.                          CASTILLO Sneakers For Men
# 4            BRUTON                              CR-1 Sneakers For Men
# 5          RapidBox  Combo Pack of 3 Casual & Sports Shoes (Sneaker...
# 6          HOTSTYLE                           Cilia Sneakers For Women
# 7            Chevit                                   Sneakers For Men
# 8              PUMA           WATERPROOF-05cFULLWHITE Sneakers For Men
# 9          Roadster                                   Sneakers For Men
# 10            asian  Perfect & Affordable Combo Pack of 02 Pairs Sn...
# 11  U.S. POLO ASSN.                                   Sneakers For Men
# ...

# %%
next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]")
next.click()

# %%
brand=[]
description=[]
price=[]
discount=[]
brands_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brands_tags[0:36]:
    brands=i.text
    brand.append(brands)
    
descriptio_tags=driver.find_elements(By.XPATH, '//*[@class="IRpwTa"]')
for i in descriptio_tags[0:36]:
    descriptio=i.text
    description.append(descriptio)
    
pric_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in pric_tags[0:36]:
    pric=i.text
    price.append(pric)
    
discoun_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discoun_tags[0:36]:
    discoun=i.text
    discount.append(discoun)

# %%
print(len(brand),len(description),len(price),len(discount))
# Out:
# 36 36 36 36

# %%
df2=pd.DataFrame({'brand':brand,'description':description,'price':price,'discount':discount})
df2
# Out:
#               brand                                        description  \
# 0              PUMA                Puma Smash v2 Buck Sneakers For Men
# 1           HimQuen  Shoes For Women's/Ladies/Female/Girls Running ...
# 2              PUMA                        Bella SL Sneakers For Women
# 3            BRUTON                           Sneaker Sneakers For Men
# 4          BERSACHE  Combo pack of 3 casual sneaker shoes for men S...
# 5           Noztile                                   Sneakers For Men
# 6            BRUTON  Trendy Fashion Sports Combo Pack Of 3 Pairs Ou...
# 7     WHITE WALKERS  Stylish & Trending Outdoor Walking Comfortable...
# 8            RINDAS  Perfect Stylish Casual Shoes For Girls & Women...
# 9              PUMA             Puma Rebound LayUp SL Sneakers For Men
# 10             PUMA                   Puma Smash Vulc Sneakers For Men
# 11         RapidBox  Mesh | Ultralightweight | Comfortable | Breath...
# ...

# %%
pd.concat([df, df1, df2])
# Out:
#               brand                                        description  \
# 0              PUMA                   Puma Smash Vulc Sneakers For Men
# 1              aadi  Mesh | Ultralightweight | Comfortable | Breath...
# 2          RED TAPE                                   Sneakers For Men
# 3   U.S. POLO ASSN.                          CASTILLO Sneakers For Men
# 4            BRUTON                              CR-1 Sneakers For Men
# ..              ...                                                ...
# 31     Robbie jones  Designer Printed Casual Sneakers Shoes Sneaker...
# 32  U.S. POLO ASSN.                                   Sneakers For Men
# 33            AMICO                            SM-734 Sneakers For Men
# 34           DUCATI                     Puma Smash v2 Sneakers For Men
# 35            Sparx  White casual, gym,training & Running sneakers ...
#
#      price discount
# 0   ₹2,317  39% off
# 1     ₹749  62% off
# 2   ₹1,499  70% off
# 3   ₹2,321  46% off
# ...

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://www.myntra.com/shoes")

# %%
#right click is not working at myntra site for scraping of data

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://amazon.in/")

# %%
laptop=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
laptop.send_keys('laptop')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#i7_filter = driver.find_element(By.XPATH,'//span[@title="Intel Core i7"]')

#i7_filter.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[3]/div/div/div/div/div/div/div/div[2]/div/div/div[1]/h2/a")
search.click()

# %%
ratings=[]
description=[]
price=[]

pric_tags=driver.find_elements(By.XPATH,'//*[@class="a-price"]')
for i in pric_tags[0:10]:
    pric=i.text
    price.append(pric)

# %%
rate_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
for i in rate_tags[0:10]:
    rate=i.text
    ratings.append(rate)

# %%
describe_tags=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')
for i in describe_tags[0:10]:
    describe=i.text
    description.append(describe)

# %%
print(len(ratings),len(description),len(price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'ratings':ratings,'description':description,'price':price})
df
# Out:
#   ratings                                        description      price
# 0      17  Sponsored\nSamsung Galaxy Book2 360 Intel 12th...    ₹97,990
# 1       9  Sponsored\nSamsung Galaxy Book2 Pro Intel 12th...  ₹1,09,990
# 2      23  Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen...    ₹62,990
# 3      25  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...    ₹56,590
# 4      19  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    ₹89,990
# 5       1  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    ₹81,990
# 6      23  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...    ₹82,400
# 7      26  Samsung Galaxy Book2 Intel 12th Gen core i7 39...    ₹79,490
# 8      16  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    ₹87,990
# 9       1  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...    ₹43,198

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://www.ambitionbox.com/")

# %%
jobs=driver.find_element(By.XPATH,"/html/body/div[1]/nav[2]/div/ul/li[5]/a")
jobs.click()

# %%
data=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input")
data.send_keys('Data Scientist')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button/span")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/p")
search.click()

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input")
location.send_keys('Noida')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label")
search.click()

# %%
name=[]
titl_tags=driver.find_elements(By.XPATH,'//div[@class="info"]')
for i in titl_tags[0:10]:
    titl=i.text
    name.append(describe)

# %%
print(len(name))
# Out:
# 10

# %%
df4=pd.DataFrame({'name':name})
df4
# Out:
#                                                 name
# 0  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 1  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 2  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 3  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 4  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 5  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 6  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 7  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 8  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...
# 9  (Renewed) Dell Intel 6th Gen Core i7-6820HQ 15...

# %%
driver=webdriver.Chrome(r"C:\Program Files\chromedriver.exe")
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("http://www.ambitionbox.com/")

# %%
jobs=driver.find_element(By.XPATH,"/html/body/div[1]/nav[2]/div/ul/li[5]/a")
jobs.click()

# %%
data=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input")
data.send_keys('Data Scientist')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button/span")
search.click()
